# %% [markdown]
# <a href="https://colab.research.google.com/github/nurshatfateh/WebScraping-NaturalLanguageProcessing/blob/main/Final_NLP_Part_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
upperframe=[]  

for page in range(10,750,10):
    print('processing page :', page)
    url = 'https://www.newagebd.net/tags/Road%20accident/'+str(page)
    print(url)

    try:
        page=requests.get(url)                            
    except Exception as e:                                        
        continue      

    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('li')
    print(len(links))
  
 
    for j in links:
        Link = ""
        try:
          Link += j.find("h3").find('a')['href'].strip()
          Date = j.find('p').find('span').text[-5:-1].strip()
          frame.append((Link,Date))
        except: 
          a=1
      
        
    upperframe.extend(frame)

data=pd.DataFrame(upperframe, columns=['Link','Date'])
data
# Out:
# processing page : 10
# https://www.newagebd.net/tags/Road%20accident/10
# 233
# processing page : 20
# https://www.newagebd.net/tags/Road%20accident/20
# 234
# processing page : 30
# https://www.newagebd.net/tags/Road%20accident/30
# 235
# processing page : 40
# https://www.newagebd.net/tags/Road%20accident/40
# 236
# processing page : 50
# https://www.newagebd.net/tags/Road%20accident/50
# 236
# processing page : 60
# https://www.newagebd.net/tags/Road%20accident/60
# 236
# processing page : 70
# https://www.newagebd.net/tags/Road%20accident/70
# 236
# processing page : 80
# https://www.newagebd.net/tags/Road%20accident/80
# 236
# processing page : 90
# https://www.newagebd.net/tags/Road%20accident/90
# 236
# processing page : 100
# https://www.newagebd.net/tags/Road%20accident/100
# 236
# processing page : 110
# https://www.newagebd.net/tags/Road%20accident/110
# 236
# processing page : 120
# https://www.newagebd.net/tags/Road%20accident/120
# 236
# processing page : 130
# ...
